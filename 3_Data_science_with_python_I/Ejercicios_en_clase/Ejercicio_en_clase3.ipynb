# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import pyplot
import pandas as pd
import requests
import os

# %% [markdown]
# #### Clasificacion de las cantidades:

# %% [markdown]
# - Catergoricas

# %% [markdown]
# - Cuantitativa

# %% [markdown]
# #### Clasificacion de las variables:

# %% [markdown]
# - Continuas

# %% [markdown]
# - Discretas

# %%
url = 'https://www.indexmundi.com/map/?t=0&v=25&r=xx&l=en'
html = requests.get(url).content
tasanac = pd.read_html(html)[2]

# %%
pd.read_html??

# %%
tasanac.head()
# Out:
#          0                                     1     2
# 0  Country  Birth rate (births/1,000 population)  Year
# 1   Angola                                    44  2017
# 2    Niger                                    44  2017
# 3     Mali                                    44  2017
# 4   Uganda                                    43  2017

# %%
url1 = 'https://www.indexmundi.com/map/?t=0&v=35&r=xx&l=en'
html1 = requests.get(url1).content
tasavih = pd.read_html(html1)[2]

# %%
tasavih.head()
# Out:
#               0                                       1     2
# 0       Country  HIV/AIDS - people living with HIV/AIDS  Year
# 1  South Africa                                 7100000  2018
# 2       Nigeria                                 3200000  2018
# 3         India                                 2100000  2018
# 4    Mozambique                                 1800000  2018

# %%
url2 = 'https://www.indexmundi.com/map/?t=0&v=85&r=xx&l=en'
html2 = requests.get(url2).content
exportaciones = pd.read_html(html2)[2]

# %%
exportaciones.head()
# Out:
#                0                    1     2
# 0        Country  Exports (Billion $)  Year
# 1          China                 2157  2017
# 2  United States                 1576  2017
# 3        Germany                 1401  2017
# 4          Japan                  683  2017

# %%
url3 = 'https://www.indexmundi.com/map/?t=0&v=89&r=xx&l=en'
html3 = requests.get(url3).content
exportaciones = pd.read_html(html3)[2]

# %%
exportaciones
# Out:
#                                      0                    1     2
# 0                              Country  Imports (Billion $)  Year
# 1                        United States                 2352  2017
# 2                                China                 1731  2017
# 3                              Germany                 1104  2017
# 4                                Japan                  626  2017
# 5                       United Kingdom                  603  2017
# 6                               France                  576  2017
# 7                            Hong Kong                  561  2017
# 8                         Korea, South                  448  2017
# 9                               Canada                  444  2017
# 10                         Netherlands                  435  2017
# 11                               India                  427  2017
# 12                               Italy                  427  2017
# ...

# %% [markdown]
# ### Planteamiento de preguntas

# %%
tabulador = pd.read_excel('tabulador_pe2019.xls', header=9)

# %%
tabulador
# Out:
#     NIVEL TIPO                            PUESTO   SUELDO BASE  \
# 0      22  NaN           GOBERNADOR/A DEL ESTADO  59804.327930
# 1      20  NaN          SECRETARIO/A DE ESTADO A  49025.945517
# 2      19  NaN  DIRECTOR/A GENERAL PARAESTATAL A  40685.951590
# 3      19  NaN          SECRETARIO/A DE ESTADO B  40685.951590
# 4      18  NaN          SECRETARIO/A DE ESTADO C  37083.708634
# 5      18  NaN                 SUBSECRETARIO/A A  37083.708634
# 6      18  NaN  DIRECTOR/A GENERAL PARAESTATAL B  37083.708634
# 7      17  NaN                 SUBSECRETARIO/A B  36196.185147
# 8      17  NaN  DIRECTOR/A GENERAL PARAESTATAL C  36196.185147
# 9      16  NaN                 SUBSECRETARIO/A C  29462.206543
# 10     16  NaN  DIRECTOR/A GENERAL PARAESTATAL D  29462.206543
# 11     16  NaN           COORDINADOR/A GENERAL A  29462.206543
# 12     15  NaN                 SUBSECRETARIO/A D  25790.604996
# 13     15  NaN           COORDINADOR/A GENERAL B  25790.604996
# ...

# %% [markdown]
# #### Preguntas que se pueden responder con esta base de datos

# %% [markdown]
# Cuanto se gana anualmente por puesto?

# %% [markdown]
# Cual es la relacion entre el nivel del puesto y el sueldo base, ayuda por servicios o apoyos familiares?

# %% [markdown]
# Cual es el promedio de cada categoria?

# %% [markdown]
# Cual es la diferencia entre la media de cada categoria y cada valor por cada clase?

# %% [markdown]
# Cuales niveles incluyen el 25%, 50% y 75% del sueldo total asignado?

# %% [markdown]
# El sueldo base se puede describir con una funcion mediante un ajuste estadistico?

# %% [markdown]
# El sueldo base es proporcional al nivel que se tiene? Lo mismo para cada categoria

# %% [markdown]
# Existe alguna distribucion en los sueldos base? Como es esta distribucion?

# %% [markdown]
# Se tienen suficientes datos para obtener buena estadistica?

# %% [markdown]
# #### Preguntas que podrian responderse con informacion complementaria

# %% [markdown]
# Cual ha sido la tasa de aumento en el sueldo base con respecto a las administraciones pasadas?

# %% [markdown]
# Es justo percibir el sueldo asignado a cada nivel?

# %% [markdown]
# Es necesario percibir el sueldo asignado a cada nivel?

# %% [markdown]
# Cual es la diferencia entre la media del sueldo base en Gto con otros estados?
