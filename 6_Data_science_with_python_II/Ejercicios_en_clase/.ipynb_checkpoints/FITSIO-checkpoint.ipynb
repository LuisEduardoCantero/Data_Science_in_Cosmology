# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
hdul=fits.open('tractor-0001m002.fits')

# %%
hdul.info()
# Out:
# Filename: tractor-0001m002.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     156   ()
#   1                1 BinTableHDU    792   1837R x 160C   [I, J, 8A, J, L, I, I, 4A, D, D, E, E, E, E, 5E, E, D, D, 2A, K, E, E, E, E, E, E, E, L, E, E, I, E, E, I, E, E, I, L, E, E, I, I, E, L, E, E, E, E, B, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, 8E, 8E, 8E, 8E, 8E, 8E, 8E, 8E, 8E, E, E, E, E, E, E, E, I, I, I, I, I, I, I, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, I, I, I, I, I, B, B, E, E, E, E, E, E, E, E, E, E, E, E, E, 8A, 11E, 11E, 11E, 11E, 11I, 11I, 11E, 11E, 11E, 11E, 11D, 11D, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
data = hdul[1].data

# %%
data_header = hdul[1].header
data_header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                 1395 / width of table in bytes
# NAXIS2  =                 1837 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                  160 / number of fields in each row
# TTYPE1  = 'release '           / label for field   1
# TFORM1  = 'I       '           / data format of field: 2-byte INTEGER
# TTYPE2  = 'brickid '           / label for field   2
# TFORM2  = 'J       '           / data format of field: 4-byte INTEGER
# TTYPE3  = 'brickname'          / label for field   3
# TFORM3  = '8A      '           / data format of field: ASCII Character
# TTYPE4  = 'objid   '           / label for field   4
# TFORM4  = 'J       '           / data format of field: 4-byte INTEGER
# ...

# %%
hdul.close()

# %%
from astropy.table import Table

# %%
data1_tab = Table.read('tractor-0001m002.fits')

# %%
data1_tab
# Out:
# <Table length=1837>
# release brickid brickname ... shapedev_e1_ivar shapedev_e2 shapedev_e2_ivar
#                           ...
#  int16   int32    bytes8  ...     float32        float32       float32
# ------- ------- --------- ... ---------------- ----------- ----------------
#    8001  328928  0001m002 ...              0.0         0.0              0.0
#    8001  328928  0001m002 ...              0.0         0.0              0.0
#    8001  328928  0001m002 ...              0.0         0.0              0.0
#    8001  328928  0001m002 ...              0.0         0.0              0.0
#    8001  328928  0001m002 ...              0.0         0.0              0.0
#    8001  328928  0001m002 ...        837.03406  0.14122897        1292.4563
#    8001  328928  0001m002 ...              0.0         0.0              0.0
#    8001  328928  0001m002 ...              0.0         0.0              0.0
#    8001  328928  0001m002 ...              0.0         0.0              0.0
# ...

# %%
ra = data1_tab['ra']
dec = data1_tab['dec']

# %%
len(ra)
# Out:
# 1837

# %%
len(dec)
# Out:
# 1837

# %%
plt.scatter(ra, dec)

# %%
dec*360
# Out:
# <Column name='dec' dtype='float64' unit='deg' length=1837>
#  -128.3459096773994
# -128.77693472045402
# -125.79483475512811
# -122.12238595044721
# -126.18986661811215
# -129.44754843124574
# -134.53117381027397
# -122.44736816710784
#  -133.3433596320523
# -126.10504208504169
#  -127.7378280634052
# -134.41167926896205
#                 ...
#  -45.54909320827691
#  -45.40425787486343
#  -45.34652925507964
#   -45.3254526176374
#  -45.14718008686828
#  -44.80840464205601
# -45.028664921346945
# -44.985995435923044
#  -44.75339574527743
#  -44.66779118477646
#  -44.74764741930736
#  -44.10123172447986

# %% [markdown]
# # asignar color con la varianza
